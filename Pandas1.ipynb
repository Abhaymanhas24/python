# %%
import pandas as pd
import numpy as np

# %%
data ={
    'Name':['Emp_'+str(i)for i in range(100)],
    'Age':np.random.randint(10,40,100),
    'City':np.random.choice(['Hyderbad','Banglore','Goa','Chennai'],size=100),
    'Salary':np.random.randint(10000,100000,100)
}
df=pd.DataFrame(data)

# %% [markdown]
# # How to store the dataFrame in form of json,csv,xlsx

# %%
df.to_csv('Employee.csv',index=False)
df.to_json('Employee.json',orient='records')

# %%
df_csv=pd.read_csv("Employee.csv")

# %%
df_csv.tail()
# Out:
#       Name  Age      City  Salary
# 95  Emp_95   31       Goa   11188
# 96  Emp_96   32   Chennai   29187
# 97  Emp_97   24       Goa   25821
# 98  Emp_98   18       Goa   99743
# 99  Emp_99   31  Banglore   95773

# %% [markdown]
# ## how to store raw unknown raw json file

# %%
import json
with open("Employee.json") as f1:
    data_json=json.load(f1)

# %%
df_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    100 non-null    object
#  1   Age     100 non-null    int64
#  2   City    100 non-null    object
#  3   Salary  100 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 3.3+ KB

# %%
df_dd=df_csv.drop_duplicates()

# %%
df_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    100 non-null    object
#  1   Age     100 non-null    int64
#  2   City    100 non-null    object
#  3   Salary  100 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 3.3+ KB

# %%
df_csv.describe()
# Out:
#               Age        Salary
# count  100.000000    100.000000
# mean    24.020000  54595.920000
# std      8.752466  27440.132399
# min     10.000000  10319.000000
# 25%     16.000000  29135.750000
# 50%     24.000000  58960.500000
# 75%     31.250000  74363.000000
# max     39.000000  99743.000000

# %%
df_exel=pd.read_excel("C:/Users/abhay.manhas/Downloads/Customer.xlsx")

# %%
df_exel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         21 non-null     int64
#  1   First_Name         21 non-null     object
#  2   Last_Name          20 non-null     object
#  3   Phone_Number       19 non-null     object
#  4   Address            21 non-null     object
#  5   Paying Customer    21 non-null     object
#  6   Do_Not_Contact     17 non-null     object
#  7   Not_Useful_Column  21 non-null     bool
# dtypes: bool(1), int64(1), object(6)
# memory usage: 1.3+ KB

# %%
dp_new=df_exel.drop(columns='Not_Useful_Column')

# %%
dp_new.head()
# Out:
#    CustomerID First_Name Last_Name  Phone_Number  \
# 0        1001      Frodo   Baggins  123-545-5421
# 1        1002       Abed     Nadir  123/643/9775
# 2        1003     Walter    /White    7066950392
# 3        1004     Dwight   Schrute  123-543-2345
# 4        1005        Jon      Snow  876|678|3469
#
#                                  Address Paying Customer Do_Not_Contact
# 0                  123 Shire Lane, Shire             Yes             No
# 1                    93 West Main Street              No            Yes
# 2                     298 Drugs Driveway               N            NaN
# 3  980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                       123 Dragons Road               Y             No

# %%
dp_new["Phone_Number"]= dp_new["Phone_Number"].str.replace('N/a','0')

# %%
dp_new["Phone_Number"]= dp_new["Phone_Number"].fillna(0)

# %%
dp_new
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White             0
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger             0
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN             0
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee             0
# 11        1012      Harry    ...Potter             0
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
dp_new[["Street_Address","State","Zip"]]=dp_new["Address"].str.split(',',n=2,expand=True)
dp_new
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White             0
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger             0
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN             0
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee             0
# 11        1012      Harry    ...Potter             0
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
dp_new=dp_new.drop_duplicates()

# %%
dp_new
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White             0
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger             0
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN             0
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee             0
# 11        1012      Harry    ...Potter             0
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
dp_new=dp_new.drop(columns="Address")

# %%
dp_new['Paying Customer'] = dp_new['Paying Customer'].replace({'Y': 'Yes', 'N': 'No'})

# %%
dp_new['Do_Not_Contact'] = dp_new['Do_Not_Contact'].replace({'Y': 'Yes', 'N': 'No'})

# %%
dp_new
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo      Baggins  123-545-5421             Yes
# 1         1002       Abed        Nadir  123/643/9775              No
# 2         1003     Walter       /White             0              No
# 3         1004     Dwight      Schrute  123-543-2345             Yes
# 4         1005        Jon         Snow  876|678|3469             Yes
# 5         1006        Ron      Swanson  304-762-2467             Yes
# 6         1007       Jeff       Winger             0              No
# 7         1008   Sherlock       Holmes  876|678|3469              No
# 8         1009    Gandalf          NaN             0             Yes
# 9         1010      Peter       Parker  123-545-5421             Yes
# 10        1011    Samwise       Gamgee             0             Yes
# 11        1012      Harry    ...Potter             0             Yes
# 12        1013        Don       Draper  123-543-2345             Yes
# ...
